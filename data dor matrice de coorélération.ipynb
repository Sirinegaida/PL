# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from scipy import stats
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder

# %%
file_path1 ='df_maincode.csv'

# %%
#importaion of the csv file
df1= pd.read_csv(file_path1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-561191a976e0> in <cell line: 2>()
#       1 #importaion of the csv file
# ----> 2 df1= pd.read_csv(file_path1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
file_path2 = 'dfn_article.csv'

# %%
#importaion of the csv file
df2= pd.read_csv(file_path2)

# %%
df2
# Out:
#       CodeArticle  Id_Article  Id_Famille  Id_Couleur
# 0        SENR200A       10615           4        1047
# 1         SENP82A       10512          10        1047
# 2        SENC139A       10176           2        1047
# 3        YHNXC12A       15216          27         122
# 4         THNS20A       11924           6         156
# ...           ...         ...         ...         ...
# 17865    JHNOA9AD       15432           0           0
# 17866    ZNMCK016       15470           0           0
# 17867   ZNFIMFRET       15531           0           0
# 17868         625       15549           0           0
# 17869         174       15605           0           0
#
# [17870 rows x 4 columns]

# %%
df2=df2.drop_duplicates()

# %%
# Concatenate along the columns CodeArticle
df_matrice=pd.merge(df1, df2[['CodeArticle','Id_Article','Id_Famille','Id_Couleur']], on='CodeArticle',how='left')
df_matrice
# Out:
#       CodeMag   Reception         Famille       nomArticle       Barcode  \
# 0       AF21C  2022-12-28       TEE-SHIRT        NOELLA MC  3.606848e+12
# 1       AF21C  2022-12-28       TEE-SHIRT      NELYA GILET  3.606848e+12
# 2       AF21C  2022-12-31    MAROQUINERIE     REXPLORATION  3.606848e+12
# 3       AF21C  2022-12-28       TEE-SHIRT       OJULION ML  3.606848e+12
# 4       AF21C  2022-12-31  PANTALON DAILY  FPOWER SKINNY T  3.606848e+12
# ...       ...         ...             ...              ...           ...
# 99989    F742  2023-01-10            PULL        AMANDA ML  3.606848e+12
# 99990    F742  2023-01-10       TEE-SHIRT   REJINA MARY ML  3.606848e+12
# 99991    F742  2023-01-10       TEE-SHIRT          LIMA MC  3.606848e+12
# 99992    F742  2023-01-10            JUPE       ICEBERG J1  3.606848e+12
# 99993    F742  2023-01-10            JUPE       KIXTIES J1  3.606848e+12
#
#       CodeCouleur Taille  PrixVente   Prix  Quantite   Remise  Total  \
# ...

# %%
df_matrice.to_csv('df_matrice.csv', index=False)

# %%
df_matrice.columns
# Out:
# Index(['CodeMag', 'Reception', 'Famille', 'nomArticle', 'Barcode',
#        'CodeCouleur', 'Taille', 'PrixVente', 'Prix', 'Quantite', 'Remise',
#        'Total', 'CodeBarre', 'CodeArticle', 'TypeVente', 'IDTicket',
#        'comparaison', 'Id_Article', 'Id_Famille', 'Id_Couleur'],
#       dtype='object')
